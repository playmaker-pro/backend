# %%
import os, sys
sys.path.insert(0, '/Users/arsen/ws/PlayMaker/webapp/')
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "backend.settings.dev")
import django
django.setup()

from data.models import Team



ts = Team.objects.all()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/logging/config.py in configure(self)
#     561                     try:
# --> 562                         handler = self.configure_handler(handlers[name])
#     563                         handler.name = name
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/logging/config.py in configure_handler(self, config)
#     734         try:
# --> 735             result = factory(**kwargs)
#     736         except TypeError as te:
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/logging/__init__.py in __init__(self, filename, mode, encoding, delay)
#    1091         else:
# ...
