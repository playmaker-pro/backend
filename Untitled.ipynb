# %%
import os, sys
sys.path.insert(0, '/Users/arsen/ws/PlayMaker/webapp/')
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "backend.settings.dev")
import django
django.setup()

from data.models import Team



ts = Team.objects.all()
print(ts.count())
# Out:
# SEO data loaded from seo.yaml
# Force to use season for dispaly metrics: 2020/2021
# ::> Loading custom local settings (local.py)
